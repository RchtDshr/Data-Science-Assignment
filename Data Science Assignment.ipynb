# %% [markdown]
# Importing packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %% [markdown]
# Getting Data

# %%
filepath='C:/Users/lenovo/Downloads/clean_df.csv'
df = pd.read_csv(filepath)

# %%
# show the first 5 rows using dataframe.head() method
print("The first 5 rows of the dataframe") 
df.head(35)
# Out:
# The first 5 rows of the dataframe
#     Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0            0          3                122  alfa-romero        std
# 1            1          3                122  alfa-romero        std
# 2            2          1                122  alfa-romero        std
# 3            3          2                164         audi        std
# 4            4          2                164         audi        std
# 5            5          2                122         audi        std
# 6            6          1                158         audi        std
# 7            7          1                122         audi        std
# 8            8          1                158         audi      turbo
# 9            9          2                192          bmw        std
# 10          10          0                192          bmw        std
# 11          11          0                188          bmw        std
# ...

# %%
df.drop(columns='Unnamed: 0', inplace=True)

# %% [markdown]
# How to Construct a Bar Graph with Overlay Using R/Python

# %%
subset_df = df[['make', 'price']]

# Grouping by 'make' and calculating the mean of 'price' for each make
grouped_df = subset_df.groupby('make')['price'].mean().reset_index()

# Sorting by average price in descending order for better visualization
grouped_df = grouped_df.sort_values(by='price', ascending=False)

# Plotting the bar graph
plt.figure(figsize=(12, 6))
bar_width = 0.4

# Bar graph for average price
plt.bar(grouped_df['make'], grouped_df['price'], color='blue', label='Average Price')

# Adding labels and title
plt.xlabel('Car Make')
plt.ylabel('Average Price')
plt.title('Bar Graph with Overlay - Average Price by Car Make')

# Showing the legend
plt.legend()

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Displaying the plot
plt.tight_layout()
plt.show()

# %%
How to Construct Contingency Tables Using R/Python

# %%
subset_columns = ['make', 'aspiration', 'num-of-doors', 'body-style']

# Creating the contingency table
contingency_table = pd.crosstab(index=df['make'], columns=[df['aspiration'], df['num-of-doors'], df['body-style']])

# Displaying the contingency table
print(contingency_table)
# Out:
# aspiration          std                                                 turbo  \
# num-of-doors       four                     two                          four
# body-style    hatchback sedan wagon convertible hardtop hatchback sedan sedan
# make
# alfa-romero           0     0     0           2       0         1     0     0
# audi                  0     3     1           0       0         0     1     1
# bmw                   0     5     0           0       0         0     3     0
# chevrolet             0     1     0           0       0         2     0     0
# dodge                 1     2     1           0       0         2     0     1
# honda                 0     4     1           0       0         7     1     0
# isuzu                 0     1     0           0       0         1     0     0
# jaguar                0     2     0           0       0         0     1     0
# mazda                 1     7     0           0       0         9     0     0
# ...

# %%
subset_columns = ['make', 'aspiration']

# Creating the contingency table
contingency_table = pd.crosstab(index=df['make'], columns=[df['aspiration']])

# Displaying the contingency table
print(contingency_table)
# Out:
# aspiration     std  turbo
# make
# alfa-romero      3      0
# audi             5      1
# bmw              8      0
# chevrolet        3      0
# dodge            6      3
# honda           13      0
# isuzu            2      0
# jaguar           3      0
# mazda           17      0
# mercedes-benz    4      4
# mercury          0      1
# mitsubishi       7      6
# nissan          17      1
# peugot           5      6
# plymouth         5      2
# porsche          4      0
# renault          2      0
# saab             4      2
# subaru          10      2
# toyota          31      1
# volkswagen      10      2
# volvo            6      5

# %%
How to Construct Histograms with Overlay Using R/Python

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataset is stored in a DataFrame named 'df'
# If not, you can read your dataset into a DataFrame using pd.read_csv() or pd.read_excel(), etc.

# Selecting a numerical column for the histogram (e.g., 'engine-size' for illustration)
numerical_column = 'engine-size'

# Filtering out missing values
data1 = df[numerical_column][df['fuel-type-diesel'] == 0].dropna()
data2 = df[numerical_column][df['fuel-type-diesel'] == 1].dropna()

# Plotting overlaid histograms
plt.hist(data1, bins=20, alpha=0.5, label='Gas', color='blue')
plt.hist(data2, bins=20, alpha=0.5, label='Diesel', color='orange')

# Adding labels and title
plt.xlabel('Engine Size')
plt.ylabel('Frequency')
plt.title('Overlaid Histograms by Fuel Type')
plt.legend()

# Display the plot
plt.show()

# %%
# Selecting a numerical column for the histogram (e.g., 'horsepower' for illustration)
numerical_column = 'horsepower'

# Filtering data based on the 'num-of-doors' column
data1 = df[numerical_column][df['num-of-doors'] == 'two']
data2 = df[numerical_column][df['num-of-doors'] == 'four']

# Plotting overlaid histograms
plt.hist(data1, bins=20, alpha=0.5, label='Two Doors', color='blue')
plt.hist(data2, bins=20, alpha=0.5, label='Four Doors', color='orange')

# Adding labels and title
plt.xlabel('Horsepower')
plt.ylabel('Frequency')
plt.title('Overlaid Histograms by Number of Doors')
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# Binning

# %%
How to Perform Binning Based on Predictive Value Using R/Python

# %%
# Convert data to correct format:
df["horsepower"]=df["horsepower"].astype(int, copy=True)
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["horsepower"])

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Since you are building 3 bins of equal length, you need 4 dividers, so numbers_generated = 4.
bins = np.linspace(min(df["horsepower"]), max(df["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
# Set group names:
group_names = ['Low', 'Medium', 'High']
# Apply the function "cut" to determine what each value of df['horsepower'] belongs to.
df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True )
df[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0          111               Low
# 1          111               Low
# 2          154            Medium
# 3          102               Low
# 4          115               Low
# 5          110               Low
# 6          110               Low
# 7          110               Low
# 8          140            Medium
# 9          101               Low
# 10         101               Low
# 11         121            Medium
# 12         121            Medium
# 13         121            Medium
# 14         182            Medium
# 15         182            Medium
# 16         182            Medium
# 17          48               Low
# 18          70               Low
# 19          70               Low

# %%
df["horsepower-binned"].value_counts()
# Out:
# Low       153
# Medium     43
# High        5
# Name: horsepower-binned, dtype: int64

# %%
# Bar graph for understanding in which bin belongs the most values
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, df["horsepower-binned"].value_counts())

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
How to Partition the Data Python

# %%
from sklearn.model_selection import train_test_split

# Selecting features (X) and target variable (y)
features = df.drop('price', axis=1)  # Assuming 'price' is the target variable
target = df['price']

# Splitting the dataset into 80% training and 20% testing
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Displaying the shape of the training and testing sets
print("Training set shape:", X_train.shape)
print("Testing set shape:", X_test.shape)
# Out:
# Training set shape: (160, 28)
# Testing set shape: (41, 28)

# %%
How to Build CART Decision Trees Using R/Python

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import preprocessing

# Assuming your dataset is stored in a DataFrame named 'df'
# If not, you can read your dataset into a DataFrame using pd.read_csv() or pd.read_excel(), etc.

# Selecting features (X) and target variable (y)
features = df.drop('price', axis=1)
target = df['price']

# Encoding categorical variables (if any)
features = pd.get_dummies(features)

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Initializing the Decision Tree Regressor
model = DecisionTreeRegressor(random_state=42)

# Training the model on the training set
model.fit(X_train, y_train)

# Making predictions on the testing set
y_pred = model.predict(X_test)

# Evaluating the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Displaying results
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 9430936.835365854
# R-squared: 0.9229163418229928

# %% [markdown]
# To build a decision tree using the Gini index for predicting the 'price' of a car, we'll use the scikit-learn library. The Gini index is commonly used for classification problems, so we'll convert the 'price' variable into a categorical variable (e.g., low, medium, high) for demonstration purposes.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn import preprocessing
import matplotlib.pyplot as plt

# Assuming your dataset is stored in a DataFrame named 'df'
# If not, you can read your dataset into a DataFrame using pd.read_csv() or pd.read_excel(), etc.

# Selecting features (X) and target variable (y)
features = df.drop('price', axis=1)
target = df['price']

# Converting 'price' into categorical labels (you can customize this based on your specific needs)
price_labels = pd.cut(target, bins=[0, 15000, 30000, float('inf')], labels=['Low', 'Medium', 'High'], include_lowest=True)

# Encoding categorical variables (if any)
features = pd.get_dummies(features)

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, price_labels, test_size=0.2, random_state=42)

# Initializing the Decision Tree Classifier with Gini index
model = DecisionTreeClassifier(criterion='gini', random_state=42)

# Training the model on the training set
model.fit(X_train, y_train)

# Making predictions on the testing set
y_pred = model.predict(X_test)

# Evaluating the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Displaying results
print(f'Accuracy: {accuracy}')
print('\nConfusion Matrix:\n', conf_matrix)
print('\nClassification Report:\n', class_report)

# Visualizing the Decision Tree
fig, ax = plt.subplots(figsize=(20, 20))
plot_tree(model, filled=True, feature_names=features.columns, class_names=model.classes_, rounded=True, fontsize=10, ax=ax)
plt.show()
# Out:
# Accuracy: 0.9024390243902439
#
# Confusion Matrix:
#  [[ 7  0  1]
#  [ 0 25  2]
#  [ 0  1  5]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       1.00      0.88      0.93         8
#          Low       0.96      0.93      0.94        27
#       Medium       0.62      0.83      0.71         6
#
#     accuracy                           0.90        41
#    macro avg       0.86      0.88      0.86        41
# weighted avg       0.92      0.90      0.91        41

# %% [markdown]
# How to Build Random Forests R/Python

# %% [markdown]
# In the context of regression tasks, like predicting the 'price' of a car, accuracy is not a suitable metric. Accuracy is commonly used for classification tasks, where the goal is to predict classes (categories) rather than continuous values. For regression tasks, metrics like mean squared error (MSE) or R-squared are more appropriate.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import preprocessing

# Assuming your dataset is stored in a DataFrame named 'df'
# If not, you can read your dataset into a DataFrame using pd.read_csv() or pd.read_excel(), etc.

# Selecting features (X) and target variable (y)
features = df.drop('price', axis=1)
target = df['price']

# Encoding categorical variables (if any)
features = pd.get_dummies(features)

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Initializing the Random Forest Regressor
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Training the model on the training set
rf_model.fit(X_train, y_train)

# Making predictions on the testing set
y_pred = rf_model.predict(X_test)

# Evaluating the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Displaying results
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 7342473.044280964
# R-squared: 0.9399863775784384

# %%
How to Perform Model Evaluation Using R/Python

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Evaluating the model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Displaying results
print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R-squared (R²): {r2}')
# Out:
# Mean Squared Error (MSE): 7342473.044280964
# Mean Absolute Error (MAE): 1748.135731707317
# R-squared (R²): 0.9399863775784384

# %%
using LR

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn import preprocessing

# Assuming your dataset is stored in a DataFrame named 'df'
# If not, you can read your dataset into a DataFrame using pd.read_csv() or pd.read_excel(), etc.

# Selecting features (X) and target variable (y)
features = df.drop('price', axis=1)
target = df['price']

# Encoding categorical variables (if any)
features = pd.get_dummies(features)

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Initializing the Linear Regression model
linear_model = LinearRegression()

# Training the model on the training set
linear_model.fit(X_train, y_train)

# Making predictions on the testing set
y_pred = linear_model.predict(X_test)

# Evaluating the model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Displaying results
print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R-squared (R²): {r2}')
# Out:
# Mean Squared Error (MSE): 8853220.07652082
# Mean Absolute Error (MAE): 1840.9026021597067
# R-squared (R²): 0.9276383033777498
